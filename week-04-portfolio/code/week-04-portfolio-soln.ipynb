# %%
import os
import sys
HOME_DIR = '/Users/anhdang/Documents/Github/COS40007-Artificial-Intelligence-for-Engineering'
os.chdir(HOME_DIR)

DATASETS_DIR = f'{HOME_DIR}/datasets'
DATA_DIR = f'{DATASETS_DIR}/09'
DATASET_FILE = f'{DATA_DIR}/vegemite.csv'

print(f'HOME_DIR: {HOME_DIR}')
print(f'DATASETS_DIR: {DATASETS_DIR}')
print(f'DATA_DIR: {DATA_DIR}')
print(f'BONING_DATASET_FILE: {DATASET_FILE}')
# Out:
# HOME_DIR: /Users/anhdang/Documents/Github/COS40007-Artificial-Intelligence-for-Engineering
# DATASETS_DIR: /Users/anhdang/Documents/Github/COS40007-Artificial-Intelligence-for-Engineering/datasets
# DATA_DIR: /Users/anhdang/Documents/Github/COS40007-Artificial-Intelligence-for-Engineering/datasets/09
# BONING_DATASET_FILE: /Users/anhdang/Documents/Github/COS40007-Artificial-Intelligence-for-Engineering/datasets/09/vegemite.csv

# %%
# !pip install --upgrade pip --quiet
# !pip install -r requirements.txt --quiet

# %%
import joblib
import math
import json
import pandas as pd
import numpy as np

from scipy.integrate import simpson as simps
from scipy.signal import find_peaks

from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV, cross_val_score, train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline


import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Preparation

# %%
# Load dataset
df = pd.read_csv(DATASET_FILE)

# Shuffle dataset
df = df.sample(frac=1).reset_index(drop=True)

# %%
 # Display the first few rows to verify
df.head()
# Out:
#    FFTE Feed tank level SP  FFTE Production solids SP  FFTE Steam pressure SP  \
# 0                     50.0                       43.0                  138.20
# 1                     50.0                       40.5                  100.00
# 2                     50.0                       40.5                   97.45
# 3                     25.0                       41.5                  135.00
# 4                     50.0                       43.0                  130.82
#
#    TFE Out flow SP  TFE Production solids SP  TFE Vacuum pressure SP  \
# 0          2991.88                      66.0                  -68.82
# 1          2066.67                      63.0                  -79.84
# 2          2525.93                      63.0                  -80.00
# 3          2038.55                       5.0                  -50.00
# 4          2846.51                      72.0                  -76.73
#
#    TFE Steam pressure SP  TFE Steam temperature SP  FFTE Feed flow SP  \
# 0                  120.0                      80.0            10130.0
# 1                  120.0                      80.0             9100.0
# 2                  120.0                      80.0             9500.0
# 3                    2.0                      80.0            18000.0
# 4                  120.0                      80.0            10200.0
#
#    FFTE Out steam temp SP  ...  TFE Out flow PV  TFE Product out temperature  \
# 0                   50.00  ...          1603.76                          0.0
# 1                   49.88  ...          2000.65                          0.0
# 2                   50.00  ...          3282.75                          0.0
# 3                   50.00  ...          3147.86                          0.0
# 4                   50.00  ...          2494.16                          0.0
#
#    TFE Production solids PV  TFE Production solids density  \
# 0                     69.85                           1.20
# 1                     63.54                           0.93
# 2                     58.03                           0.89
# 3                      0.00                           0.86
# 4                     -7.20                           1.35
#
#    TFE Steam pressure PV  TFE Steam temperature  TFE Tank level  \
# 0                 120.56                  72.36           22.79
# 1                 119.91                  82.68           82.22
# 2                 125.36                  57.55           84.10
# 3                   1.98                  74.86           64.25
# 4                 119.91                  82.93           32.19
#
#    TFE Temperature  TFE Vacuum pressure PV  Class
# 0             73.0                  -73.86      2
# 1             83.0                  -58.34      1
# 2             69.0                  -54.10      2
# 3             75.0                    2.30      1
# 4             83.0                  -54.81      2
#
# [5 rows x 47 columns]

# %%
# Inspect the structure and types of the dataset
dataset_info = df.info()

# Display summary statistics of the dataset
summary_statistics = df.describe()

# Check for unique values in each column
unique_values = df.nunique()

dataset_info, summary_statistics, unique_values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15237 entries, 0 to 15236
# Data columns (total 47 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   FFTE Feed tank level SP        15237 non-null  float64
#  1   FFTE Production solids SP      15237 non-null  float64
#  2   FFTE Steam pressure SP         15237 non-null  float64
#  3   TFE Out flow SP                15237 non-null  float64
#  4   TFE Production solids SP       15237 non-null  float64
#  5   TFE Vacuum pressure SP         15237 non-null  float64
#  6   TFE Steam pressure SP          15237 non-null  float64
#  7   TFE Steam temperature SP       15237 non-null  float64
#  8   FFTE Feed flow SP              15237 non-null  float64
#  9   FFTE Out steam temp SP         15237 non-null  float64
#  10  Extract tank Level             15237 non-null  float64
#  11  Extract tank Out flow PV       15237 non-null  float64
#  12  FFTE Discharge density         15237 non-null  float64
#  13  FFTE Discharge solids          15237 non-null  float64
#  14  FFTE Feed flow rate PV         15237 non-null  float64
#  15  FFTE Feed tank level PV        15237 non-null  float64
#  16  FFTE Heat temperature 1        15237 non-null  float64
#  17  FFTE Heat temperature 2        15237 non-null  float64
#  18  FFTE Heat temperature 3        15237 non-null  float64
#  19  FFTE Out steam temp PV         15237 non-null  float64
#  20  FFTE Production solids PV      15237 non-null  float64
#  21  FFTE Pump 1                    15237 non-null  float64
#  22  FFTE Pump 1 - 2                15237 non-null  float64
#  23  FFTE Pump 2                    15237 non-null  float64
#  24  FFTE Steam pressure PV         15237 non-null  float64
#  25  FFTE Temperature 1 - 1         15237 non-null  float64
#  26  FFTE Temperature 1 - 2         15237 non-null  float64
#  27  FFTE Temperature 2 - 1         15237 non-null  float64
#  28  FFTE Temperature 2 - 2         15237 non-null  float64
#  29  FFTE Temperature 3 - 1         15237 non-null  float64
#  30  FFTE Temperature 3 - 2         15237 non-null  float64
#  31  FFTE Unk Temperature           15237 non-null  float64
#  32  TFE Feed pump                  15237 non-null  float64
#  33  TFE Input flow PV              15237 non-null  float64
#  34  TFE Level                      15237 non-null  float64
#  35  TFE Motor current              15237 non-null  float64
#  36  TFE Motor speed                15237 non-null  float64
#  37  TFE Out flow PV                15237 non-null  float64
#  38  TFE Product out temperature    15237 non-null  float64
#  39  TFE Production solids PV       15237 non-null  float64
#  40  TFE Production solids density  15237 non-null  float64
#  41  TFE Steam pressure PV          15237 non-null  float64
#  42  TFE Steam temperature          15237 non-null  float64
#  43  TFE Tank level                 15237 non-null  float64
#  44  TFE Temperature                15237 non-null  float64
#  45  TFE Vacuum pressure PV         15237 non-null  float64
#  46  Class                          15237 non-null  int64
# dtypes: float64(46), int64(1)
# memory usage: 5.5 MB
# (None,
#         FFTE Feed tank level SP  FFTE Production solids SP  \
#  count             15237.000000               15237.000000
#  mean                 46.660760                  41.834045
#  std                   8.504626                   1.142426
#  min                  25.000000                  39.000000
#  25%                  50.000000                  41.110000
#  50%                  50.000000                  42.000000
#  75%                  50.000000                  43.000000
#  max                  50.000000                  43.000000
#
#         FFTE Steam pressure SP  TFE Out flow SP  TFE Production solids SP  \
#  count            15237.000000     15237.000000              15237.000000
#  mean               118.767011      2434.316757                 62.635479
#  std                 17.303951       395.339898                 15.118098
#  min                 60.000000      1687.180000                  0.000000
#  25%                106.000000      2066.670000                 62.000000
#  50%                120.000000      2296.300000                 65.000000
#  75%                130.000000      2846.510000                 71.000000
#  max                225.000000      3012.560000                 98.000000
#
#         TFE Vacuum pressure SP  TFE Steam pressure SP  \
#  count            15237.000000           15237.000000
#  mean               -65.393245             114.905117
#  std                 13.616923              25.043754
#  min                -80.000000               2.000000
#  25%                -78.760000             120.000000
#  50%                -68.790000             120.000000
#  75%                -53.640000             120.000000
#  max                -36.370000             135.000000
#
#         TFE Steam temperature SP  FFTE Feed flow SP  FFTE Out steam temp SP  \
#  count                   15237.0       15237.000000            15237.000000
#  mean                       80.0       10041.919669               49.668441
#  std                         0.0        1409.314110                2.043087
#  min                        80.0        1100.000000               40.710000
#  25%                        80.0        9400.000000               50.000000
#  50%                        80.0        9600.000000               50.000000
#  75%                        80.0       10200.000000               50.000000
#  max                        80.0       18000.000000               54.380000
#
#         ...  TFE Out flow PV  TFE Product out temperature  \
#  count  ...     15237.000000                      15237.0
#  mean   ...      2397.382250                          0.0
#  std    ...      1371.097955                          0.0
#  min    ...         0.000000                          0.0
#  25%    ...      1603.760000                          0.0
#  50%    ...      2020.100000                          0.0
#  75%    ...      2750.320000                          0.0
#  max    ...     17880.030000                          0.0
#
#         TFE Production solids PV  TFE Production solids density  \
#  count              15237.000000                   15237.000000
#  mean                  59.880919                       1.114700
#  std                   18.831331                       0.176049
#  min                  -25.700000                       0.500000
#  25%                   58.460000                       1.000000
#  50%                   64.920000                       1.200000
#  75%                   69.720000                       1.230000
#  max                  103.200000                       1.420000
#
#         TFE Steam pressure PV  TFE Steam temperature  TFE Tank level  \
#  count           15237.000000           15237.000000    15237.000000
#  mean              111.837051              72.514360       68.614778
#  std                30.552954               8.279227       21.411287
#  min                 0.000000              40.120000       10.710000
#  25%               119.910000              67.240000       53.940000
#  50%               119.910000              71.980000       80.880000
#  75%               120.230000              77.430000       83.160000
#  max               168.940000             105.360000       95.600000
#
#         TFE Temperature  TFE Vacuum pressure PV         Class
#  count     15237.000000            15237.000000  15237.000000
#  mean         76.271248              -63.980396      1.321979
#  std           6.806914               19.008813      0.751753
#  min          56.000000              -87.270000      0.000000
#  25%          71.000000              -77.390000      1.000000
#  50%          75.000000              -70.360000      1.000000
#  75%          81.000000              -56.910000      2.000000
#  max         106.000000                4.040000      2.000000
#
#  [8 rows x 47 columns],
#  FFTE Feed tank level SP             3
#  FFTE Production solids SP          12
#  FFTE Steam pressure SP           2251
#  TFE Out flow SP                    53
#  TFE Production solids SP           96
#  TFE Vacuum pressure SP           3182
#  TFE Steam pressure SP              74
#  TFE Steam temperature SP            1
#  FFTE Feed flow SP                  50
#  FFTE Out steam temp SP             12
#  Extract tank Level               5341
#  Extract tank Out flow PV          649
#  FFTE Discharge density             40
#  FFTE Discharge solids            1145
#  FFTE Feed flow rate PV            487
#  FFTE Feed tank level PV          1019
#  FFTE Heat temperature 1          1612
#  FFTE Heat temperature 2          1290
#  FFTE Heat temperature 3          1587
#  FFTE Out steam temp PV            205
#  FFTE Production solids PV        1536
#  FFTE Pump 1                         5
#  FFTE Pump 1 - 2                     4
#  FFTE Pump 2                         5
#  FFTE Steam pressure PV           1507
#  FFTE Temperature 1 - 1            749
#  FFTE Temperature 1 - 2            727
#  FFTE Temperature 2 - 1            468
#  FFTE Temperature 2 - 2            561
#  FFTE Temperature 3 - 1            705
#  FFTE Temperature 3 - 2            774
#  FFTE Unk Temperature              927
#  TFE Feed pump                    1439
#  TFE Input flow PV                 735
#  TFE Level                        1417
#  TFE Motor current                1094
#  TFE Motor speed                     3
#  TFE Out flow PV                  1105
#  TFE Product out temperature         1
#  TFE Production solids PV         1657
#  TFE Production solids density      50
#  TFE Steam pressure PV             326
#  TFE Steam temperature            1309
#  TFE Tank level                   4716
#  TFE Temperature                    45
#  TFE Vacuum pressure PV            207
#  Class                               3
#  dtype: int64)

# %%
# Check for missing values
missing_values = df.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %%
# Plot the distribution of the 'Class' variable
sns.countplot(x='Class', data=df)
plt.title('Distribution of Classes')
plt.show()

# %%
# Compute the correlation matrix
correlation_matrix = df.corr()

# Plot the correlation matrix
plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Select some key features for visualization
key_features = ['FFTE Production solids SP', 'TFE Steam pressure SP', 'TFE Production solids SP', 'TFE Vacuum pressure SP']

# Plot histograms for key features
df[key_features].hist(figsize=(12, 8), bins=30, layout=(2, 2))
plt.suptitle('Distribution of Key Features')
plt.show()

# %%
# Remove constant features
df = df.loc[:, df.nunique() > 1]

# Select features with a low correlation to others or use dimensionality reduction methods
selected_features = df.columns[df.columns.str.endswith('SP')]  # Using only SP features for this model

selected_features.tolist()
# Out:
# ['FFTE Feed tank level SP',
#  'FFTE Production solids SP',
#  'FFTE Steam pressure SP',
#  'TFE Out flow SP',
#  'TFE Production solids SP',
#  'TFE Vacuum pressure SP',
#  'TFE Steam pressure SP',
#  'FFTE Feed flow SP',
#  'FFTE Out steam temp SP']

# %%
# Define the threshold for few unique values
threshold = 10

# Identify columns with fewer unique values than the threshold
few_unique_values_columns = df.nunique()[df.nunique() < threshold]

print(few_unique_values_columns)
# Out:
# FFTE Feed tank level SP    3
# FFTE Pump 1                5
# FFTE Pump 1 - 2            4
# FFTE Pump 2                5
# TFE Motor speed            3
# Class                      3
# dtype: int64

# %%
# Convert these columns to categorical type
for col in few_unique_values_columns.index:
    df[col] = df[col].astype('category')

# Verify conversion
print(df.dtypes)
# Out:
# FFTE Feed tank level SP          category
# FFTE Production solids SP         float64
# FFTE Steam pressure SP            float64
# TFE Out flow SP                   float64
# TFE Production solids SP          float64
# TFE Vacuum pressure SP            float64
# TFE Steam pressure SP             float64
# FFTE Feed flow SP                 float64
# FFTE Out steam temp SP            float64
# Extract tank Level                float64
# Extract tank Out flow PV          float64
# FFTE Discharge density            float64
# FFTE Discharge solids             float64
# FFTE Feed flow rate PV            float64
# FFTE Feed tank level PV           float64
# FFTE Heat temperature 1           float64
# FFTE Heat temperature 2           float64
# FFTE Heat temperature 3           float64
# FFTE Out steam temp PV            float64
# FFTE Production solids PV         float64
# FFTE Pump 1                      category
# FFTE Pump 1 - 2                  category
# FFTE Pump 2                      category
# FFTE Steam pressure PV            float64
# FFTE Temperature 1 - 1            float64
# FFTE Temperature 1 - 2            float64
# FFTE Temperature 2 - 1            float64
# FFTE Temperature 2 - 2            float64
# FFTE Temperature 3 - 1            float64
# FFTE Temperature 3 - 2            float64
# FFTE Unk Temperature              float64
# TFE Feed pump                     float64
# TFE Input flow PV                 float64
# TFE Level                         float64
# TFE Motor current                 float64
# TFE Motor speed                  category
# TFE Out flow PV                   float64
# TFE Production solids PV          float64
# TFE Production solids density     float64
# TFE Steam pressure PV             float64
# TFE Steam temperature             float64
# TFE Tank level                    float64
# TFE Temperature                   float64
# TFE Vacuum pressure PV            float64
# Class                            category
# dtype: object

# %%
# Split the dataset into training and testing before oversampling
X_train, X_test, y_train, y_test = train_test_split(df[selected_features], df['Class'], test_size=1000, stratify=df['Class'], random_state=42)

# %% [markdown]
# # Feature selection, Model Training and Evaluation

# %%
# Define the oversampler (SMOTE)
oversampler = SMOTE(sampling_strategy='auto', random_state=42)

# Apply oversampling to the training data only
X_train_resampled, y_train_resampled = oversampler.fit_resample(X_train, y_train)

# Split the resampled data into training and testing
X_train_resampled, X_val, y_train_resampled, y_val = train_test_split(X_train_resampled, y_train_resampled, test_size=0.2, stratify=y_train_resampled, random_state=42)

# To view the number of features in the final dataset
num_features = X_train_resampled.shape[1]  # After oversampling
print(f'The final training dataset includes {num_features} features.')
# Out:
# The final training dataset includes 9 features.

# %%
print(f'DF Size: {df.shape}')
# Out:
# DF Size: (15237, 45)

# %%
print(f'Train Size: {X_train.shape[0]}')
print(f'Train Resampled Size: {X_train_resampled.shape[0]}')
# Out:
# Train Size: 14237
# Train Resampled Size: 16927

# %%
# Define pipelines to handle missing values for models that need it
gb_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # Impute missing values
    ('model', GradientBoostingClassifier())
])

svm_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # Impute missing values
    ('model', SVC())
])

knn_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # Impute missing values
    ('model', KNeighborsClassifier())
])

# Models to train (using pipelines for models that require imputation)
models = {
    'DecisionTree': DecisionTreeClassifier(),
    'RandomForest': RandomForestClassifier(),
    'GradientBoosting': gb_pipeline,  # Using the pipeline for Gradient Boosting
    'SVM': svm_pipeline,              # Using the pipeline for SVM
    'KNN': knn_pipeline               # Using the pipeline for KNN
}

# Train and evaluate each model using the resampled training data and the untouched test data
results = {}
for name, model in models.items():
    model.fit(X_train_resampled, y_train_resampled)  # Train on the resampled training set
    predictions = model.predict(X_val)  # Evaluate on the original test set
    results[name] = {
        'report': classification_report(y_val, predictions, output_dict=True),
        'conf_matrix': confusion_matrix(y_val, predictions)
    }

# Display results
results
# Out:
# {'DecisionTree': {'report': {'0': {'precision': 0.9413817166782973,
#     'recall': 0.9567375886524823,
#     'f1-score': 0.9489975378121702,
#     'support': 1410.0},
#    '1': {'precision': 0.9221514508138712,
#     'recall': 0.923458540042523,
#     'f1-score': 0.9228045325779037,
#     'support': 1411.0},
#    '2': {'precision': 0.943001443001443,
#     'recall': 0.926293408929837,
#     'f1-score': 0.9345727565248481,
#     'support': 1411.0},
#    'accuracy': 0.9354914933837429,
#    'macro avg': {'precision': 0.9355115368312038,
#     'recall': 0.9354965125416141,
#     'f1-score': 0.9354582756383074,
#     'support': 4232.0},
#    'weighted avg': {'precision': 0.9355101497376671,
#     'recall': 0.9354914933837429,
#     'f1-score': 0.9354550763797596,
#     'support': 4232.0}},
#   'conf_matrix': array([[1349,   41,   20],
#          [  49, 1303,   59],
#          [  35,   69, 1307]])},
#  'RandomForest': {'report': {'0': {'precision': 0.9530154277699859,
#     'recall': 0.9638297872340426,
#     'f1-score': 0.9583921015514809,
#     'support': 1410.0},
#    '1': {'precision': 0.9440113394755493,
#     'recall': 0.9440113394755493,
#     'f1-score': 0.9440113394755493,
#     'support': 1411.0},
#    '2': {'precision': 0.9584229390681004,
#     'recall': 0.9475549255846917,
#     'f1-score': 0.9529579472558802,
#     'support': 1411.0},
#    'accuracy': 0.9517958412098299,
#    'macro avg': {'precision': 0.9518165687712119,
#     'recall': 0.9517986840980944,
#     'f1-score': 0.9517871294276367,
#     'support': 4232.0},
#    'weighted avg': {'precision': 0.9518162854869494,
#     'recall': 0.9517958412098299,
#     'f1-score': 0.9517855687064356,
#     'support': 4232.0}},
#   'conf_matrix': array([[1359,   36,   15],
#          [  36, 1332,   43],
#          [  31,   43, 1337]])},
#  'GradientBoosting': {'report': {'0': {'precision': 0.7898326100433974,
#     'recall': 0.9035460992907801,
#     'f1-score': 0.842871319880913,
#     'support': 1410.0},
#    '1': {'precision': 0.8212025316455697,
#     'recall': 0.735648476257973,
#     'f1-score': 0.7760747663551402,
#     'support': 1411.0},
#    '2': {'precision': 0.822140221402214,
#     'recall': 0.7895109851169383,
#     'f1-score': 0.8054953000723066,
#     'support': 1411.0},
#    'accuracy': 0.8095463137996219,
#    'macro avg': {'precision': 0.811058454363727,
#     'recall': 0.8095685202218972,
#     'f1-score': 0.8081471287694533,
#     'support': 4232.0},
#    'weighted avg': {'precision': 0.8110634699224039,
#     'recall': 0.8095463137996219,
#     'f1-score': 0.8081389236203249,
#     'support': 4232.0}},
#   'conf_matrix': array([[1274,   68,   68],
#          [ 200, 1038,  173],
#          [ 139,  158, 1114]])},
#  'SVM': {'report': {'0': {'precision': 0.39784117193523516,
#     'recall': 0.7319148936170212,
#     'f1-score': 0.5154845154845155,
#     'support': 1410.0},
#    '1': {'precision': 0.47368421052631576,
#     'recall': 0.012756909992912827,
#     'f1-score': 0.024844720496894408,
#     'support': 1411.0},
#    '2': {'precision': 0.463125,
#     'recall': 0.5251594613749114,
#     'f1-score': 0.4921952839588177,
#     'support': 1411.0},
#    'accuracy': 0.42320415879017015,
#    'macro avg': {'precision': 0.444883460820517,
#     'recall': 0.42327708832828187,
#     'f1-score': 0.34417483998007586,
#     'support': 4232.0},
#    'weighted avg': {'precision': 0.44489457667327814,
#     'recall': 0.42320415879017015,
#     'f1-score': 0.3441343603781135,
#     'support': 4232.0}},
#   'conf_matrix': array([[1032,    0,  378],
#          [ 912,   18,  481],
#          [ 650,   20,  741]])},
#  'KNN': {'report': {'0': {'precision': 0.9124236252545825,
#     'recall': 0.9531914893617022,
#     'f1-score': 0.9323621227887617,
#     'support': 1410.0},
#    '1': {'precision': 0.8997194950911641,
#     'recall': 0.9092841956059532,
#     'f1-score': 0.9044765597462108,
#     'support': 1411.0},
#    '2': {'precision': 0.9437359339834959,
#     'recall': 0.891566265060241,
#     'f1-score': 0.9169096209912536,
#     'support': 1411.0},
#    'accuracy': 0.9180056710775047,
#    'macro avg': {'precision': 0.9186263514430809,
#     'recall': 0.9180139833426321,
#     'f1-score': 0.9179161011754088,
#     'support': 4232.0},
#    'weighted avg': {'precision': 0.9186278171156206,
#     'recall': 0.9180056710775047,
#     'f1-score': 0.9179126876542336,
#     'support': 4232.0}},
#   'conf_matrix': array([[1344,   49,   17],
#          [  70, 1283,   58],
#          [  59,   94, 1258]])}}

# %%
# Initialize lists to store comparison data
model_names = []
accuracies = []
precisions = []
recalls = []
f1_scores = []
confusion_matrices = []

# Initialize variables to store the best model information
best_model_name = None
best_model_accuracy = 0

# Extract data from results dictionary
for model_name, model_results in results.items():
    model_names.append(model_name)
    accuracies.append(model_results['report']['accuracy'])
    precisions.append(model_results['report']['macro avg']['precision'])
    recalls.append(model_results['report']['macro avg']['recall'])
    f1_scores.append(model_results['report']['macro avg']['f1-score'])
    confusion_matrices.append(model_results['conf_matrix'])
    
    model_accuracy = model_results['report']['accuracy']
    if model_accuracy > best_model_accuracy:
        best_model_name = model_name
        best_model_accuracy = model_accuracy

# Create a DataFrame for the comparison table
comparison_df = pd.DataFrame({
    'Model': model_names,
    'Accuracy': accuracies,
    'Precision (Macro Avg)': precisions,
    'Recall (Macro Avg)': recalls,
    'F1-Score (Macro Avg)': f1_scores
})

# Function to plot table
def plot_table(df, title):
    fig, ax = plt.subplots(figsize=(10, 2))  # set size frame
    ax.axis('tight')
    ax.axis('off')
    ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')
    plt.title(title)
    plt.show()

# Display the comparison table as an image
plot_table(comparison_df, "Model Comparison Table")

# Function to plot confusion matrix
def plot_confusion_matrix(cm, model_name):
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Pred 0', 'Pred 1', 'Pred 2'], yticklabels=['True 0', 'True 1', 'True 2'])
    plt.title(f"Confusion Matrix for {model_name}")
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# Display the confusion matrices as images
for model_name, conf_matrix in zip(model_names, confusion_matrices):
    plot_confusion_matrix(conf_matrix, model_name)

print(f"The best model is {best_model_name} with an accuracy of {best_model_accuracy:.3f}")
# Out:
# The best model is RandomForest with an accuracy of 0.952

# %%
# Save the best model
joblib.dump(models['RandomForest'], 'week-04-portfolio/models/random_forest_model.pkl')
# Out:
# ['week-04-portfolio/models/random_forest_model.pkl']

# %% [markdown]
# # ML to AI

# %%
# Test the model on unseen data points (already done in the previous steps)
final_predictions = models['RandomForest'].predict(X_test)

# Evaluate the performance on the unseen data points
final_report = classification_report(y_test, final_predictions, output_dict=True)
final_conf_matrix = confusion_matrix(y_test, final_predictions)

# Convert classification report to DataFrame for better visualization
final_report_df = pd.DataFrame(final_report).transpose()

# Plot the final classification report as a table
plot_table(final_report_df, "Final Classification Report: RandomForest")

# Plot the final confusion matrix
plot_confusion_matrix(final_conf_matrix, "Final Confusion Matrix: RandomForest")

# %%
# Evaluate RandomForest on the Test Dataset
rf_test_predictions = models['RandomForest'].predict(X_test)
rf_test_report = classification_report(y_test, rf_test_predictions, output_dict=True)
rf_test_conf_matrix = confusion_matrix(y_test, rf_test_predictions)

# Evaluate RandomForest on the Evaluation Dataset
rf_eval_predictions = models['RandomForest'].predict(X_val)
rf_eval_report = classification_report(y_val, rf_eval_predictions, output_dict=True)
rf_eval_conf_matrix = confusion_matrix(y_val, rf_eval_predictions)

# Convert classification reports to DataFrames for better visualization
rf_test_report_df = pd.DataFrame(rf_test_report).transpose()
rf_eval_report_df = pd.DataFrame(rf_eval_report).transpose()

# Function to plot comparison table
def plot_comparison_table(df1, df2, title1, title2):
    fig, axes = plt.subplots(1, 2, figsize=(20, 5))
    axes[0].axis('tight')
    axes[0].axis('off')
    axes[0].table(cellText=df1.values, colLabels=df1.columns, cellLoc='center', loc='center')
    axes[0].set_title(title1)
    
    axes[1].axis('tight')
    axes[1].axis('off')
    axes[1].table(cellText=df2.values, colLabels=df2.columns, cellLoc='center', loc='center')
    axes[1].set_title(title2)
    
    plt.show()

# Function to plot confusion matrix comparison
def plot_confusion_matrix_comparison(cm1, cm2, title1, title2):
    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    
    sns.heatmap(cm1, annot=True, fmt="d", cmap="Blues", xticklabels=['Pred 0', 'Pred 1', 'Pred 2'], yticklabels=['True 0', 'True 1', 'True 2'], ax=axes[0])
    axes[0].set_title(title1)
    axes[0].set_ylabel('Actual')
    axes[0].set_xlabel('Predicted')
    
    sns.heatmap(cm2, annot=True, fmt="d", cmap="Blues", xticklabels=['Pred 0', 'Pred 1', 'Pred 2'], yticklabels=['True 0', 'True 1', 'True 2'], ax=axes[1])
    axes[1].set_title(title2)
    axes[1].set_ylabel('Actual')
    axes[1].set_xlabel('Predicted')
    
    plt.show()

# Plot the classification report comparison
plot_comparison_table(rf_test_report_df, rf_eval_report_df, "Test Dataset Classification Report: RandomForest", "Evaluation Dataset Classification Report: RandomForest")

# Plot the confusion matrix comparison
plot_confusion_matrix_comparison(rf_test_conf_matrix, rf_eval_conf_matrix, "Test Dataset Confusion Matrix: RandomForest", "Evaluation Dataset Confusion Matrix: RandomForest")

# %% [markdown]
# # Develop Rules from the ML Model

# %%
# Step 1: Filter the Data to Include Only `SP` Features
sp_features = [col for col in df.columns if col.endswith('SP')]
X_sp = df[sp_features]
y_sp = df['Class']

# Step 2: Train a Decision Tree Classifier Using Only `SP` Features
decision_tree_sp = DecisionTreeClassifier(random_state=42)
decision_tree_sp.fit(X_sp, y_sp)

# Step 3: Visualize the Decision Tree
tree_rules = export_text(decision_tree_sp, feature_names=sp_features)
print(tree_rules)
# Out:
# |--- TFE Out flow SP <= 2249.11
# |   |--- FFTE Steam pressure SP <= 119.98
# |   |   |--- TFE Out flow SP <= 2100.70
# |   |   |   |--- TFE Vacuum pressure SP <= -67.99
# |   |   |   |   |--- FFTE Feed flow SP <= 9395.00
# |   |   |   |   |   |--- TFE Production solids SP <= 64.25
# |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 103.50
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 94.00
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 52.75
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  52.75
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 60.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  60.00
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -76.47
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -76.47
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  94.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- FFTE Steam pressure SP >  103.50
# |   |   |   |   |   |   |   |--- TFE Production solids SP <= 57.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Production solids SP >  57.50
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -79.95
# |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP <= 122.50
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 112.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  112.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP >  122.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -79.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -79.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -79.95
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 49.58
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  49.58
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 2029.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  2029.76
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- TFE Production solids SP >  64.25
# |   |   |   |   |   |   |--- FFTE Production solids SP <= 41.83
# |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 49.94
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 44.99
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  44.99
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -70.90
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 108.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  108.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -70.90
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 49.58
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  49.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  49.94
# |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP <= 122.50
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 50.56
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 102.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  102.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  50.56
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 109.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  109.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP >  122.50
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 2029.76
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  2029.76
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- FFTE Production solids SP >  41.83
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9235.00
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -77.21
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -77.21
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -73.05
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9035.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9035.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -73.05
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -70.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -70.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9235.00
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 67.50
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 1915.36
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -79.81
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -79.81
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  1915.36
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  67.50
# |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP <= 122.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -79.92
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -79.92
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP >  122.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 1915.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  1915.36
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- FFTE Feed flow SP >  9395.00
# |   |   |   |   |   |--- TFE Out flow SP <= 1991.99
# |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 104.50
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 97.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  97.50
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9750.00
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 102.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  102.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9750.00
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 60.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -72.98
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -72.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  60.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -79.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -79.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- FFTE Steam pressure SP >  104.50
# |   |   |   |   |   |   |   |--- TFE Steam pressure SP <= 127.50
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 65.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  65.50
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 109.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -79.26
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -79.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  109.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- TFE Steam pressure SP >  127.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- TFE Out flow SP >  1991.99
# |   |   |   |   |   |   |--- TFE Production solids SP <= 59.50
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9850.00
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 2060.24
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 46.75
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -74.65
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -74.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  46.75
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  2060.24
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9500.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9500.00
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -79.92
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -79.92
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9850.00
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- TFE Production solids SP >  59.50
# |   |   |   |   |   |   |   |--- FFTE Production solids SP <= 41.83
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 62.50
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 105.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 61.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  61.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  105.50
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 108.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  108.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  62.50
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9550.00
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP <= 41.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP >  41.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9550.00
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 107.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  107.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- FFTE Production solids SP >  41.83
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 68.50
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed tank level SP <= 37.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed tank level SP >  37.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  68.50
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 69.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  69.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- TFE Vacuum pressure SP >  -67.99
# |   |   |   |   |--- TFE Steam pressure SP <= 122.50
# |   |   |   |   |   |--- FFTE Feed flow SP <= 9750.00
# |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9550.00
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 111.00
# |   |   |   |   |   |   |   |   |--- FFTE Feed tank level SP <= 37.50
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 2074.30
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 92.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  92.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  2074.30
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- FFTE Feed tank level SP >  37.50
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 59.50
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP <= 41.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP >  41.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  59.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 1747.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  1747.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  111.00
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9350.00
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 116.44
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  116.44
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 66.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  66.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9350.00
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 64.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  64.00
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed tank level SP <= 37.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed tank level SP >  37.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- FFTE Feed flow SP >  9550.00
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -66.43
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 102.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  102.00
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 50.25
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 113.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  113.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  50.25
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -66.43
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 28.25
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 95.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  95.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  28.25
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 2060.24
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  2060.24
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 112.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  112.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- FFTE Feed flow SP >  9750.00
# |   |   |   |   |   |   |--- FFTE Production solids SP <= 41.00
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9850.00
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -65.85
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -65.85
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9850.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- FFTE Production solids SP >  41.00
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9850.00
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -62.06
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -62.06
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9850.00
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- TFE Steam pressure SP >  122.50
# |   |   |   |   |   |--- TFE Production solids SP <= 71.50
# |   |   |   |   |   |   |--- TFE Out flow SP <= 1781.58
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -61.54
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -63.63
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 67.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  67.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -63.63
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -61.54
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Out flow SP >  1781.58
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- TFE Production solids SP >  71.50
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -46.14
# |   |   |   |   |   |   |   |--- FFTE Feed tank level SP <= 37.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- FFTE Feed tank level SP >  37.50
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -58.40
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -64.99
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -66.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -66.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -64.99
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -62.51
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -62.51
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -58.40
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -46.14
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- TFE Out flow SP >  2100.70
# |   |   |   |--- FFTE Feed flow SP <= 9215.00
# |   |   |   |   |--- FFTE Production solids SP <= 41.17
# |   |   |   |   |   |--- FFTE Feed flow SP <= 9115.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- FFTE Feed flow SP >  9115.00
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- FFTE Production solids SP >  41.17
# |   |   |   |   |   |--- FFTE Production solids SP <= 41.75
# |   |   |   |   |   |   |--- TFE Production solids SP <= 61.00
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- TFE Production solids SP >  61.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- FFTE Production solids SP >  41.75
# |   |   |   |   |   |   |--- TFE Production solids SP <= 71.50
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 8985.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  8985.00
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 69.50
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -56.51
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -79.98
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -79.98
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -56.51
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9135.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9135.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  69.50
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -76.80
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -76.80
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -69.28
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -69.28
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- TFE Production solids SP >  71.50
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -68.33
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 107.00
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -74.65
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -74.65
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -74.28
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -74.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  107.00
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -68.33
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 99.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  99.50
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -61.10
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -63.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -63.49
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -61.10
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- FFTE Feed flow SP >  9215.00
# |   |   |   |   |--- FFTE Steam pressure SP <= 106.43
# |   |   |   |   |   |--- TFE Out flow SP <= 2154.76
# |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9265.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- FFTE Feed flow SP >  9265.00
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 101.00
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -62.23
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed tank level SP <= 37.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed tank level SP >  37.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -79.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -79.97
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -62.23
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9450.00
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -51.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -51.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9450.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  101.00
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 105.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  105.50
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -63.21
# |   |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP <= 122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP >  122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -63.21
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- TFE Out flow SP >  2154.76
# |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 50.37
# |   |   |   |   |   |   |   |--- TFE Out flow SP <= 2215.20
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 68.50
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 64.00
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 50.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  50.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  64.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  68.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Out flow SP >  2215.20
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- FFTE Out steam temp SP >  50.37
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- FFTE Steam pressure SP >  106.43
# |   |   |   |   |   |--- FFTE Feed flow SP <= 9535.00
# |   |   |   |   |   |   |--- TFE Out flow SP <= 2215.20
# |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 50.06
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9450.00
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9265.00
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 112.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  112.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9265.00
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 49.94
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  49.94
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9450.00
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -64.75
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -64.75
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  50.06
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 112.78
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 50.23
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  50.23
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 50.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  50.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  112.78
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 119.87
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 50.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  50.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  119.87
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP <= 41.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP >  41.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- TFE Out flow SP >  2215.20
# |   |   |   |   |   |   |   |--- TFE Out flow SP <= 2217.26
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- TFE Out flow SP >  2217.26
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 49.64
# |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP <= 122.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP >  122.50
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 44.99
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  44.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  49.64
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 65.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -71.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -71.16
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  65.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -61.56
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -61.56
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |--- FFTE Feed flow SP >  9535.00
# |   |   |   |   |   |   |--- FFTE Production solids SP <= 42.50
# |   |   |   |   |   |   |   |--- TFE Out flow SP <= 2228.06
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 57.50
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -66.08
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -70.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -70.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -66.08
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  57.50
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -79.98
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP <= 41.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP >  41.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -79.98
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- TFE Out flow SP >  2228.06
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- FFTE Production solids SP >  42.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |--- FFTE Steam pressure SP >  119.98
# |   |   |--- TFE Out flow SP <= 2036.03
# |   |   |   |--- FFTE Steam pressure SP <= 143.55
# |   |   |   |   |--- TFE Steam pressure SP <= 96.90
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- TFE Steam pressure SP >  96.90
# |   |   |   |   |   |--- TFE Vacuum pressure SP <= -64.65
# |   |   |   |   |   |   |--- FFTE Production solids SP <= 39.75
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9450.00
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9385.00
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9340.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9340.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9385.00
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 128.08
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 63.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  63.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  128.08
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 129.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  129.97
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9450.00
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- FFTE Production solids SP >  39.75
# |   |   |   |   |   |   |   |--- TFE Production solids SP <= 72.50
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 50.25
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 64.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP <= 127.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP >  127.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  64.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP <= 122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP >  122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  50.25
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 67.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP <= 122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP >  122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  67.50
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 127.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  127.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- TFE Production solids SP >  72.50
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 2014.46
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 50.05
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 127.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  127.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  50.05
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  2014.46
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- TFE Vacuum pressure SP >  -64.65
# |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 137.50
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 129.26
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9385.00
# |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP <= 122.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -60.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -60.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP >  122.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9385.00
# |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP <= 41.59
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 63.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  63.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP >  41.59
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP <= 42.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP >  42.14
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  129.26
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 74.00
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 1729.31
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  1729.31
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP <= 39.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP >  39.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  74.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- FFTE Steam pressure SP >  137.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- FFTE Steam pressure SP >  143.55
# |   |   |   |   |--- FFTE Production solids SP <= 41.75
# |   |   |   |   |   |--- FFTE Steam pressure SP <= 144.51
# |   |   |   |   |   |   |--- TFE Production solids SP <= 67.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Production solids SP >  67.00
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- FFTE Steam pressure SP >  144.51
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- FFTE Production solids SP >  41.75
# |   |   |   |   |   |--- TFE Out flow SP <= 1877.09
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- TFE Out flow SP >  1877.09
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- TFE Out flow SP >  2036.03
# |   |   |   |--- TFE Out flow SP <= 2154.76
# |   |   |   |   |--- TFE Production solids SP <= 58.50
# |   |   |   |   |   |--- FFTE Steam pressure SP <= 190.00
# |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 123.78
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 121.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  121.50
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -48.51
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -62.17
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -62.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -62.69
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -62.17
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -55.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -55.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -48.51
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- FFTE Steam pressure SP >  123.78
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- FFTE Steam pressure SP >  190.00
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- TFE Production solids SP >  58.50
# |   |   |   |   |   |--- FFTE Feed flow SP <= 9550.00
# |   |   |   |   |   |   |--- FFTE Production solids SP <= 41.00
# |   |   |   |   |   |   |   |--- TFE Out flow SP <= 2093.07
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 49.58
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  49.58
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 122.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 62.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  62.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  122.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- TFE Out flow SP >  2093.07
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 122.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  122.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- FFTE Production solids SP >  41.00
# |   |   |   |   |   |   |   |--- TFE Steam pressure SP <= 122.50
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9395.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9395.00
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 64.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  64.50
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 122.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  122.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |--- TFE Steam pressure SP >  122.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- FFTE Feed flow SP >  9550.00
# |   |   |   |   |   |   |--- TFE Out flow SP <= 2100.70
# |   |   |   |   |   |   |   |--- TFE Out flow SP <= 2052.61
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 64.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  64.00
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Out flow SP >  2052.61
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 122.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  122.50
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -52.67
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -52.67
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 131.38
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  131.38
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Out flow SP >  2100.70
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- TFE Out flow SP >  2154.76
# |   |   |   |   |--- FFTE Feed flow SP <= 10350.00
# |   |   |   |   |   |--- TFE Production solids SP <= 72.50
# |   |   |   |   |   |   |--- FFTE Production solids SP <= 42.50
# |   |   |   |   |   |   |   |--- TFE Out flow SP <= 2178.90
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Out flow SP >  2178.90
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9395.00
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 129.92
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 120.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  120.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  129.92
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 147.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# ...
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  84.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -63.50
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 85.50
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 49.58
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 109.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  109.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  49.58
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 119.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  119.86
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  85.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- FFTE Steam pressure SP >  121.86
# |   |   |   |--- FFTE Out steam temp SP <= 49.94
# |   |   |   |   |--- FFTE Feed flow SP <= 9350.00
# |   |   |   |   |   |--- FFTE Steam pressure SP <= 127.50
# |   |   |   |   |   |   |--- FFTE Production solids SP <= 39.75
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -74.75
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -74.75
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -74.46
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -74.46
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- FFTE Production solids SP >  39.75
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- FFTE Steam pressure SP >  127.50
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -75.69
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -78.72
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -78.72
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -77.06
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -77.06
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -76.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -76.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -75.69
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- FFTE Feed flow SP >  9350.00
# |   |   |   |   |   |--- TFE Production solids SP <= 22.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- TFE Production solids SP >  22.00
# |   |   |   |   |   |   |--- FFTE Production solids SP <= 41.87
# |   |   |   |   |   |   |   |--- TFE Production solids SP <= 66.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- TFE Production solids SP >  66.50
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -67.92
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -79.72
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -79.72
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -75.49
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -75.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -67.92
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- FFTE Production solids SP >  41.87
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- FFTE Out steam temp SP >  49.94
# |   |   |   |   |--- TFE Production solids SP <= 82.00
# |   |   |   |   |   |--- TFE Production solids SP <= 20.00
# |   |   |   |   |   |   |--- TFE Out flow SP <= 2917.68
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- TFE Out flow SP >  2917.68
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- TFE Production solids SP >  20.00
# |   |   |   |   |   |   |--- TFE Out flow SP <= 2990.36
# |   |   |   |   |   |   |   |--- TFE Out flow SP <= 2644.40
# |   |   |   |   |   |   |   |   |--- FFTE Production solids SP <= 39.75
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -56.51
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -56.51
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Production solids SP >  39.75
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 2276.06
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed tank level SP <= 37.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed tank level SP >  37.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  2276.06
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 124.91
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  124.91
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |--- TFE Out flow SP >  2644.40
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 134.76
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 72.50
# |   |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP <= 117.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- TFE Steam pressure SP >  117.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  72.50
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 125.52
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  125.52
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  134.76
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 140.06
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP <= 42.64
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP >  42.64
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  140.06
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 50.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  50.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- TFE Out flow SP >  2990.36
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- TFE Production solids SP >  82.00
# |   |   |   |   |   |--- TFE Vacuum pressure SP <= -50.42
# |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 151.97
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- FFTE Steam pressure SP >  151.97
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 152.44
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  152.44
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- TFE Vacuum pressure SP >  -50.42
# |   |   |   |   |   |   |--- class: 0
# |   |--- FFTE Out steam temp SP >  50.23
# |   |   |--- TFE Out flow SP <= 2717.04
# |   |   |   |--- FFTE Steam pressure SP <= 127.69
# |   |   |   |   |--- FFTE Out steam temp SP <= 50.37
# |   |   |   |   |   |--- FFTE Steam pressure SP <= 120.88
# |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 120.83
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- FFTE Steam pressure SP >  120.83
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- FFTE Steam pressure SP >  120.88
# |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 127.55
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- FFTE Steam pressure SP >  127.55
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- FFTE Out steam temp SP >  50.37
# |   |   |   |   |   |--- FFTE Steam pressure SP <= 77.50
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -59.20
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -64.99
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -76.19
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -78.10
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -79.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -79.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -78.10
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -76.19
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -64.99
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -59.20
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -45.34
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -45.34
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -44.70
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -44.70
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -43.73
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -44.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -44.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -43.73
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- FFTE Steam pressure SP >  77.50
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -79.92
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 9450.00
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  9450.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -79.92
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- FFTE Steam pressure SP >  127.69
# |   |   |   |   |--- class: 1
# |   |   |--- TFE Out flow SP >  2717.04
# |   |   |   |--- FFTE Feed flow SP <= 10250.00
# |   |   |   |   |--- TFE Out flow SP <= 2822.79
# |   |   |   |   |   |--- FFTE Steam pressure SP <= 127.00
# |   |   |   |   |   |   |--- FFTE Feed tank level SP <= 37.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- FFTE Feed tank level SP >  37.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- FFTE Steam pressure SP >  127.00
# |   |   |   |   |   |   |--- TFE Production solids SP <= 70.50
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -79.90
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 68.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  68.00
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed tank level SP <= 37.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed tank level SP >  37.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -79.90
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- TFE Production solids SP >  70.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- TFE Out flow SP >  2822.79
# |   |   |   |   |   |--- FFTE Steam pressure SP <= 127.91
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -36.44
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -36.44
# |   |   |   |   |   |   |   |--- TFE Production solids SP <= 78.50
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 10100.00
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  10100.00
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed tank level SP <= 37.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed tank level SP >  37.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- TFE Production solids SP >  78.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- FFTE Steam pressure SP >  127.91
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- FFTE Feed flow SP >  10250.00
# |   |   |   |   |--- TFE Production solids SP <= 80.00
# |   |   |   |   |   |--- TFE Steam pressure SP <= 85.00
# |   |   |   |   |   |   |--- TFE Production solids SP <= 71.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Production solids SP >  71.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- TFE Steam pressure SP >  85.00
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -71.45
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -71.71
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 133.37
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  133.37
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -75.11
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -75.11
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -73.82
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -73.82
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -71.71
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -71.45
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -36.66
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -36.66
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -36.46
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -36.46
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- TFE Production solids SP >  80.00
# |   |   |   |   |   |--- TFE Steam pressure SP <= 115.00
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- TFE Steam pressure SP >  115.00
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -36.40
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -36.40
# |   |   |   |   |   |   |   |--- TFE Production solids SP <= 86.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- TFE Production solids SP >  86.50
# |   |   |   |   |   |   |   |   |--- class: 1
